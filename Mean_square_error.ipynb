# %% [markdown]
# <a href="https://colab.research.google.com/github/amritsinchan/predictions_ml/blob/master/Mean_square_error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
n=200
x=np.linspace(0, 2*np.pi, n)
sine_values=np.sin(x)

# %%
plt.plot(x,sine_values)

# %%
noise=0.5
noisy_sine_values=sine_values+ np.random.uniform(-noise, noise, n)
plt.plot(x, noisy_sine_values, color='r')
plt.plot(x,sine_values,linewidth=3)

# %%
error_value=(1/n) * sum(np.power(sine_values-noisy_sine_values,2))
error_value
# Out:
# 0.08564170995290266

# %%
mean_squared_error(sine_values, noisy_sine_values)
# Out:
# 0.08564170995290254
